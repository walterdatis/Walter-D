# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # PandasA2 - FOR CREDIT
#
# ## DTSC-520: Fundamentals of Data Science
#
# ## Name:

# %% [markdown]
# ### Basic Instructions:
#
# - Don't rename this notebook file. It must be **'PandasA2credit.ipynb'.**
# - Everything is case sensitive, so BE CAREFUL
# - For this assignment load but DO NOT INSTALL NumPy and Pandas: run the following at the top of your script and then complete the questions:
#
# ```python
# import numpy as np
# import pandas as pd
# ```
#
# - Assume all arrays are NumPy arrays, all Series are Pandas series, etc., unless otherwise specified.
# - After you create the object (e.g., Q1), DO NOT PRINT! Your file should something look like this:
#
# ```python
# Q1 = [‘Hello’]
# Q2 = x[3:]
# ```
#
# #### Before attempting these make sure to watch ‘CodeGrade Walkthrough’ in module 1 - if you do not you will not understand how assignments work!
#
# **For reference:**
#
# - [CodeGrade tips and FAQ](https://docs.google.com/document/d/11EUSOpdZNPz8eRXNYpLDF8auxnXB4h6beoblekTCk1c/edit#heading=h.o6mnnzkfwuso)
#
# - [CodeGrade - What to do if my code doesn’t work?](https://docs.google.com/document/d/1oCb797TKnMvTgROCgnrqwjBZvfi7Pnhj2gFZCv4HjRI/edit#heading=h.ckjs685ktluh)

# %% [markdown]
# ### Q1:
# Create a **series** containing odd numbers `3` to `11`. Called it **q1**.
#
# Assign just the **values** of **q1** to **Q1**.

# %%
import pandas as pd

q1 = pd.Series([3, 5, 7, 9, 11])
Q1 = q1.values

# %% [markdown]
# ### Q2:
# Assign just the indices of **q1** to **Q2**.

# %%
Q2 = q1.index

# %% [markdown]
# ### Q3:
# Index to obtain the **third value** of **q1**. Assign it to **Q3**.

# %%
Q3 = q1[2]

# %% [markdown]
# ### Q4:
# Slice **q1** to obtain the following:
#
#     2    7
#     3    9
#     dtype: int64
#
# Assign it to **Q4**.

# %%
Q4 = q1[2:4]

# %% [markdown]
# ### Q5:
#
# Create the following **series**:
#
#     three      3
#     five       5
#     seven      7
#     nine       9
#     eleven    11
#     dtype: int64
#
# Assign it to **Q5**.

# %%
Q5 = pd.Series([3, 5, 7, 9, 11], index =['three', 'five', 'seven', 'nine', 'eleven'])

# %% [markdown]
# ### Q6:
#
# Create the following dictionary and called it **q6**:
#
#     {'Da': 'ta', 'Sc': 'ie', 'nc': 'ef', 'or': 'all'}
#
# Create a **series** from the **q6** dictionary and assign it to **Q6**.

# %%
q6 = {'Da': 'ta', 'Sc': 'ie', 'nc': 'ef', 'or': 'all'}
Q6 = pd.Series(q6)

# %% [markdown]
# ### Q7:
#
# Index the **Q6** series to obtain the following:
#
#     ef
#
# Assign it to **Q7**.

# %%
Q7 = Q6['nc']

# %% [markdown]
# ### Q8:
#
# Slice the **Q6** series to obtain the following:
#
#     Sc     ie
#     nc     ef
#     or     all
#     dtype: object
#
# Assign it to **Q8**.

# %%
Q8 = Q6['Sc':]

# %% [markdown]
# ### Q9:
#
# Create **series** from the following two dictionaries:
#
#     {'A': 'a', 'B': 'b', 'C': 'c'}
#     {'A':  1, 'B': 2, 'C': 3}
#
# Then create a **dataframe** from those series to obtain the following:
#
# |       | lowercase | numbers       |
# |-------|--------|--------|
# | A     | a      | 1      |
# | B     | b      | 2      |
# | C     | c      | 3     |
#
# Assign it to **Q9**.

# %%
diction1 = {'A': 'a', 'B': 'b', 'C': 'c'}
diction2 = {'A': 1, 'B': 2, 'C': 3}
Q9 = pd.DataFrame({'lowercase': diction1, 'numbers': diction2})
Q9
# Out:
#   lowercase  numbers
# A         a        1
# B         b        2
# C         c        3

# %% [markdown]
# ### Q10 and Q11:
#
# Assign **Q9**’s **row** and **column** indices to **Q10** and **Q11**, respectively

# %%
Q10 = Q9.index
Q11 = Q9.columns

# %% [markdown]
# ### Q12:
#
# Index **Q9** to obtain the following:
#
#     A   1
#     B   2
#     C   3
#     Name: numbers, dtype: int64
#
# Assign it to **Q12**.

# %%
Q12 = Q9['numbers']

# %% [markdown]
# This material is for enrolled students' academic use only and protected under U.S. Copyright Laws. This content must not be shared outside the confines of this course, in line with Eastern University's academic integrity policies. Unauthorized reproduction, distribution, or transmission of this material, including but not limited to posting on third-party platforms like GitHub, is strictly prohibited and may lead to disciplinary action. You may not alter or remove any copyright or other notice from copies of any content taken from BrightSpace or Eastern University’s website.
#
# © Copyright Notice 2024, Eastern University - All Rights Reserved
